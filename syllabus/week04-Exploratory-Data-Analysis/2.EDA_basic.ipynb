# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## Insurance Dataset using DuckDB
#
# This notebook performs exploratory data analysis on the insurance dataset located in the bronze layer.
#
# Goals:
# - Demonstrate EDA workflow
# - Use DuckDB to query CSV files
# - Generate visual insights
# - Prepare for Bronze → Silver → Gold pipeline

# %% [markdown]
# ## 1. Setup Environment

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2. Connect to DuckDB

# %%
con = duckdb.connect('insurance_eda.duckdb')

# %%
print("con=", con)
# Out:
# con= <_duckdb.DuckDBPyConnection object at 0x115dffab0>

# %% [markdown]
# ## 3. Load Bronze Data (All CSV Files)

# %%
df = con.execute("""
SELECT *
FROM read_csv_auto('./data/insurance.*.csv')
""").df()
df.head()
# Out:
#    age  gender    bmi  children  smoker     region   charges
# 0   22  female  23.20         1   False  northwest   5605.93
# 1   54    male  30.60         0   False  northeast   7118.87
# 2   48    male  31.31         0    True  southwest  40381.51
# 3   38  female  27.49         0    True  southwest  21178.05
# 4   38    male  33.10         0   False  northwest  12829.41

# %% [markdown]
# ## 4. Basic Dataset Information

# %%
df.shape
# Out:
# (6121, 7)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# gender       object
# bmi         float64
# children      int64
# smoker         bool
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# ## 5. Summary Statistics

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  6121.000000  6121.000000  6121.000000   6121.000000
# mean     41.070740    30.106844     1.090508  18454.733181
# std      13.652577     6.076884     1.272501  12628.757374
# min      18.000000    15.500000     0.000000    200.000000
# 25%      29.000000    25.970000     0.000000   9025.100000
# 50%      41.000000    30.080000     1.000000  14816.250000
# 75%      53.000000    34.150000     2.000000  26046.920000
# max      65.000000    52.000000     5.000000  61974.250000

# %% [markdown]
# ## 6. Missing Values

# %%
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ## 7. Age Distribution

# %%
plt.figure(figsize=(6,4))
plt.hist(df['age'], bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 8. BMI Distribution

# %%
plt.figure(figsize=(6,4))
plt.hist(df['bmi'], bins=20)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 9. Charges Distribution

# %%
plt.figure(figsize=(6,4))
plt.hist(df['charges'], bins=30)
plt.title('Insurance Charges Distribution')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 10. Gender Distribution

# %%
df['gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# ## 11. Region Distribution

# %%
df['region'].value_counts().plot(kind='bar')
plt.title('Region Distribution')
plt.show()

# %% [markdown]
# ## 12. Smokers vs Charges

# %%
sns.boxplot(x='smoker', y='charges', data=df)
plt.title('Charges: Smokers vs Non-Smokers')
plt.show()

# %% [markdown]
# ## 13. BMI vs Charges

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['bmi'], df['charges'])
plt.title('BMI vs Charges')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# ## 14. Average Charges by Region

# %%
region_charges = con.execute("""
SELECT region, AVG(charges) avg_charges
FROM df
GROUP BY region
ORDER BY avg_charges DESC
""").df()

region_charges.plot(kind='bar', x='region', y='avg_charges')
plt.title('Average Charges by Region')
plt.ylabel('Average Charges')
plt.show()

# %% [markdown]
# ## 15. Correlation Matrix

# %%
corr = df[['age','bmi','children','charges']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Key Insights
# - Smokers tend to have significantly higher insurance charges.
# - Age appears positively correlated with charges.
# - BMI shows moderate correlation with charges.
# - Regional differences are relatively small.
#
# Next step: move from **Bronze → Silver → Gold** in a Medallion Architecture pipeline.
