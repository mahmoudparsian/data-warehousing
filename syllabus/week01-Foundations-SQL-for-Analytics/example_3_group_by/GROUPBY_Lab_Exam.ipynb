# %% [markdown]
# # 🧪 LAB + EXAM — GROUP BY (Student Version)
#
# Instructions: Answer the following using SQL GROUP BY.

# %% [markdown]
# ## 🧱 Setup

# %%
import duckdb
con = duckdb.connect()

con.execute("""
CREATE OR REPLACE TABLE sales AS
SELECT * FROM read_csv_auto('sales.csv');
""")

# %% [markdown]
# ### 1. Find total revenue per country.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 2. Find total revenue per product.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 3. Find number of transactions per gender.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 4. Find revenue per age group (18–29, 30–49, 50+).
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 5. Find monthly revenue (derive from transaction_date).
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 6. Find top 5 products by revenue.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 7. Find average order value per country.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 8. Find revenue per day of week.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 9. Find revenue per quarter.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# ### 10. Find country-product revenue matrix.
# Write your SQL below:

# %%
# YOUR SQL HERE

# %% [markdown]
# # 🏆 FINAL EXAM QUESTIONS

# %% [markdown]
# - Explain the difference between GROUP BY and window functions.

# %% [markdown]
# - Why should derived columns be created in Silver instead of Bronze?

# %% [markdown]
# - Write SQL to find top 3 products per country using ranking.

# %% [markdown]
# - Given sales data, how would you design a Gold table for executives?
